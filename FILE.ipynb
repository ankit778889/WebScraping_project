# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
class webscrap: 
    def dataextraction(self,link):
        headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
        data = requests.get(url=link, headers=headers)
        soup = BeautifulSoup(data.content)
        return soup
    def filemaker(self,filename,soup):
        fp=open(filename,'w',encoding='utf-8')
        fp=fp.write(str(soup))

# %%
URL='https://www.imdb.com/title/tt0268093/?ref_=nv_sr_srsg_0_tt_7_nm_1_in_0_q_ramayan'
ankit=webscrap()
soup=ankit.dataextraction(URL)
filename='ankit.txt'
ankit.filemaker(filename,soup)

# %%
temp = open('ankit.txt','r',encoding='utf-8')
c = ''
dt = []
j = 0
while(j < len(temp.readline())):
    j  = j + 1
    for i in temp.readline():
        c = c + i
        dt.append(c)
    c = ''

# %%
dt
# Out:
# ['<',
#  '<h',
#  '<ht',
#  '<htm',
#  '<html',
#  '<html ',
#  '<html l',
#  '<html la',
#  '<html lan',
#  '<html lang',
#  '<html lang=',
#  '<html lang="',
#  '<html lang="e',
#  '<html lang="en',
#  '<html lang="en-',
#  '<html lang="en-U',
#  '<html lang="en-US',
#  '<html lang="en-US"',
#  '<html lang="en-US" ',
#  '<html lang="en-US" x',
#  '<html lang="en-US" xm',
#  '<html lang="en-US" xml',
#  '<html lang="en-US" xmln',
#  '<html lang="en-US" xmlns',
#  '<html lang="en-US" xmlns:',
#  '<html lang="en-US" xmlns:f',
#  '<html lang="en-US" xmlns:fb',
#  '<html lang="en-US" xmlns:fb=',
#  '<html lang="en-US" xmlns:fb="',
#  '<html lang="en-US" xmlns:fb="h',
#  '<html lang="en-US" xmlns:fb="ht',
#  '<html lang="en-US" xmlns:fb="htt',
#  '<html lang="en-US" xmlns:fb="http',
#  '<html lang="en-US" xmlns:fb="http:',
#  '<html lang="en-US" xmlns:fb="http:/',
#  '<html lang="en-US" xmlns:fb="http://',
#  '<html lang="en-US" xmlns:fb="http://w',
#  '<html lang="en-US" xmlns:fb="http://ww',
#  '<html lang="en-US" xmlns:fb="http://www',
#  '<html lang="en-US" xmlns:fb="http://www.',
#  '<html lang="en-US" xmlns:fb="http://www.f',
#  '<html lang="en-US" xmlns:fb="http://www.fa',
#  '<html lang="en-US" xmlns:fb="http://www.fac',
#  '<html lang="en-US" xmlns:fb="http://www.face',
#  '<html lang="en-US" xmlns:fb="http://www.faceb',
#  '<html lang="en-US" xmlns:fb="http://www.facebo',
#  '<html lang="en-US" xmlns:fb="http://www.faceboo',
#  '<html lang="en-US" xmlns:fb="http://www.facebook',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.c',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.co',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/20',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/200',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/f',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fb',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbm',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml"',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" x',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xm',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xml',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmln',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:o',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og=',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="h',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="ht',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="htt',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http:',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http:/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://o',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://op',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ope',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://open',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://openg',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengr',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengra',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengrap',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphp',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphpr',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphpro',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprot',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphproto',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotoc',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotoco',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.o',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.or',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/s',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/sc',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/sch',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/sche',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schem',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><h',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><he',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><hea',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><m',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><me',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><met',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta c',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta ch',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta cha',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta char',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta chars',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charse',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset=',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="u',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="ut',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><m',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><me',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><met',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta c',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta co',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta con',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta cont',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta conte',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta conten',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content=',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="w',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="wi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="wid',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="widt',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=d',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=de',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=dev',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=devi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=devic',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-w',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-wi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-wid',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-widt',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width"',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" n',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" na',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" nam',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name=',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="v',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="vi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="vie',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="view',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewp',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewpo',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewpor',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><s',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><sc',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><scr',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><scri',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><scrip',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>i',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(t',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(ty',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(type',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeo',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof u',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof ue',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet =',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet ==',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet ===',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'f',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'fu',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'fun',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'func',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'funct',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'functi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'functio',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\')',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ u',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ ue',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'b',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\',',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'L',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'Lo',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'Loa',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'Load',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadT',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTit',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitl',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\'',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\',',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {w',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb:',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1})',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1});',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); ',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }<',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</s',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</sc',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</scr',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</scri',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</scrip',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><s',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><sc',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><scr',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><scri',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><scrip',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>w',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>wi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>win',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>wind',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>windo',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.a',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.ad',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.add',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addE',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEv',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEve',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEven',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEvent',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventL',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventLi',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventLis',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventList',
#  '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === \'function\'){ uet(\'bb\', \'LoadTitle\', {wb: 1}); }</script><script>window.addEventListe',
# ...
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, ',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, U',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, Us',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, Use',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User ',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User R',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ra',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Rat',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Rati',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratin',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Rating',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings,',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, ',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, S',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Sy',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Syn',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Syno',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synop',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synops',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsi',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis,',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, ',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, T',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Tr',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Tra',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Trai',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Trail',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Traile',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Trailer',
#  '    })</script><title>Ramayan (TV Series 1987–1988) - IMDb</title><meta content="Ramayan: Created by Ramanand Sagar. With Arun Govil, Deepika Chikhalia, Sunil Lahri, Arvind Trivedi. An adaptation of the ancient epic in which the exiled Prince Rama and his brother Laxman set out to save Rama\'s wife, Sita, who has been kidnapped by the demon king of Lanka Ravana." data-id="main" name="description"/><meta content="Reviews, Showtimes, DVDs, Photos, User Ratings, Synopsis, Trailers',
#  ...]

# %%
s=set(dt)
dt=list(s)

# %%
len(dt)
# Out:
# 5694

# %%
dt[0]
# Out:
# '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://'

# %%
dt = dt[0]

# %%
dt
# Out:
# '<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://'

# %%
dt  = dt.rstrip().split('>')

# %%
dt
# Out:
# ['<html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://']

# %%
result = []
for z in dt:
    if 'Ramayan' in z:
        print(z)
        result.append(z)
        print()

# %%
result[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 result[0]
#
# IndexError: list index out of range

# %%
NAME:  ANKIT YADAV 
TRAINER NAME: SHUBHAM VISHWAKARMA
BATCH: DATA ANALYST
MODULE: PYTHON
BATCH TIME: 11AM - 1PM
